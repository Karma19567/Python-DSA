# %% [markdown]
# ### 1.Convert days to seconds

# %%
def seconds():
    return day*24*60*60

day=int(input("Number of days:")) #number of days
print(seconds())
# Out:
# 172800

# %% [markdown]
# ### 2.Volume of sphere

# %%
radius = int(input("Enter the radius of the sphere:"))
pi = 3.14
print("Volume of sphere:", (4 / 3) * pi * radius** 3)
# Out:
# Volume of sphere: 33.49333333333333

# %% [markdown]
# ### 3.Perimeter and Area of a Square

# %%
side= int(input("Enter the side of the square:"))

def perimeter():
    return side*4
def area():
    return side**2
print("Perimeter of square:", perimeter())
print("Area of square:", area())
# Out:
# Perimeter of square: 20
# Area of square: 25

# %% [markdown]
# ###  4.Determine letter casing

# %%
letter= (input("Enter a letter:"))

def casing():
    if not letter.isalpha():
        return "Not a letter"
    if letter == letter.upper():
        return "Uppercase"
    else:
        return "Lowercase"
casing()
# Out:
# 'Not a letter'

# %% [markdown]
# ### 5. Psuedo-code

# %%
x=0
y=20
while y>6:
    y=y-4
    x=x+y/2
    print(x)
# Out:
# 8.0
# 14.0
# 18.0
# 20.0

# %% [markdown]
# ###  6.Input values in an array

# %%
Array= []
for i in range(5):
    Array.append(int(input("Enter a number:")))
print(Array)
# Out:
# [15, 5, 8, 6, 3]
